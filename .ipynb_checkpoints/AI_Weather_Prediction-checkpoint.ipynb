# %% [markdown]
# # Objectives

# %% [markdown]
# - [x] get data from database
# - [ ] data wrangling
# - [ ] ml model
# - [ ] compare with traditional prediction

# %% [markdown]
# # source

# %% [markdown]
#  data provided by Openweathermap

# %% [markdown]
# # settings

# %%
# settings
# display all outputs
from IPython.core.interactiveshell import InteractiveShell  
InteractiveShell.ast_node_interactivity = "all"
#To revert to the original setting :
# InteractiveShell.ast_node_interactivity = "last_expr"

# %% [markdown]
# # Imports

# %%
# os
import os

#import time
import time
import datetime as dt

#googlesheets
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g

# data analysis and wrangling
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random 

# visualization and reporting
import pandas_profiling # dataframe profiling @
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import calmap

# Humid air model
from media_model_humid_air import h_humid_air,T_dew, rho_Humid_air, Ha_air

# %% [markdown]
# # Data imports

# %% [markdown]
# ## Historical weather

# %% [markdown]
# ### google sheet authentication

# %%
#authentication to google api using JSON credential file
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('api_data/WDcred.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### get data

# %%
#get historical weather berlin sheet
hist_weather = client.open('current_weather_berlin').sheet1

data = hist_weather.get_all_values()
headers = data.pop(0)

df_historical = pd.DataFrame(data, columns=headers)

# %%
#df_historical.tail()

# %% [markdown]
# ## get Openweathermap forecast

# %% [markdown]
# ###  Authentication

# %%
#authentication to google api using JSON credential file
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('api_data/WDcred2.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### Get Data

# %%
# open workbook
forecast_weather = client.open('forecast_weather_berlin')

# %%
#see all worksheets
#forecast_weather.worksheets()

# %%
# dataframe dictionary with all data
my_dfs={}
for worksheet in forecast_weather.worksheets():
    data = worksheet.get_all_values()
    headers = data.pop(0)
    name = str(worksheet)
    name = "df_"+name.split("'")[1].split(" ")[0]  
    df = pd.DataFrame(data, columns=headers)
    my_dfs[name]=df

# %%
#display data
if False:
    for key in my_dfs.keys():
        print(40*'-'+'\n'+key)
        my_dfs[key].head(5)
        print(40*'-')

# %%
df_hist=df_historical
my_dfs2=my_dfs

# %%
df_historical.tail()
# Out:
#                 datetime temperature humidity pressure windspeed winddir  \
# 622  2020-04-15 08:29:02        5.63       72     1021       6.7     260
# 623  2020-04-15 09:27:40        6.38       70     1022       7.2     270
# 624  2020-04-15 10:33:26        8.16       65     1022       8.2     270
# 625  2020-04-15 11:26:12        9.12       65     1022       7.7     260
# 626  2020-04-15 12:35:55       11.72       53     1021       7.2     270
#
#     cloudcoverage rain snow weather       description weathericon sunrisetime  \
# 622            75    0    0  Clouds     broken clouds         04d    06:07:39
# 623            40    0    0  Clouds  scattered clouds         03d    06:07:39
# 624            75    0    0  Clouds     broken clouds         04d    06:07:39
# 625            75    0    0  Clouds     broken clouds         04d    06:07:39
# 626            20    0    0  Clouds        few clouds         02d    06:07:39
#
#     sunsettime
# 622   20:04:32
# 623   20:04:32
# 624   20:04:32
# 625   20:04:32
# 626   20:04:32

# %% [markdown]
# # Wrangle

# %% [markdown]
# ## get ride of sunrise and sunset

# %%
df_hist.drop('sunrisetime',axis =1, inplace=True)
df_hist.drop('sunsettime',axis =1, inplace=True)

# %% [markdown]
# ## df_forecast column rename

# %%
for key in my_dfs2.keys():
    my_dfs2[key].rename(columns={
        '':'datetime',
        "temp": "temperature",
        "humidity": "humidity",
        "pressure": "pressure",
        "wind_speed": "windspeed",
        "wind_dir": "winddir",
        "rain3h":"rain",
        "snow3h":"snow",
        "cloudcoverage": "cloudcoverage",
        "weather": "weather",
        "description": "description",
        "icon": "weathericon"},inplace=True)
#df_fore.columns

# %% [markdown]
# ## join df

# %%
name='df_c'
my_dfs2[name]=df_hist

# %% [markdown]
# ## drop icon

# %%
for key in my_dfs2.keys():
    my_dfs2[key].drop('weathericon',axis =1, inplace=True)

# %% [markdown]
# ## string to numeric values

# %%
for key in my_dfs2.keys():
    cols=['temperature', 'humidity', 'pressure', 'windspeed','winddir','cloudcoverage','rain','snow']
    for col in cols:
        my_dfs2[key][col]= pd.to_numeric(my_dfs2[key][col], errors='coerce')

# %% [markdown]
# ## String to datetime

# %%
for key in my_dfs2.keys():
    my_dfs2[key]['datetime']= pd.to_datetime(my_dfs2[key]['datetime'], errors='coerce')

# %% [markdown]
# ## weather and description

# %%
for key in my_dfs2.keys():
    my_dfs2[key]['weather_description']=my_dfs2[key]['weather']+' : '+my_dfs2[key]['description']
    my_dfs2[key].drop(['weather','description'],axis=1,inplace=True)

# %% [markdown]
# ## Deal with Na

# %%
for key in my_dfs2.keys():
    my_dfs2[key]['winddir'].fillna(399,inplace=True)

# %% [markdown]
# ## Creation new value

# %%
for key in my_dfs2.keys():  
    # absolute humidity
    my_dfs2[key]['humidity_abs']=round(my_dfs2[key].apply(lambda x: Ha_air(x['temperature']+273.15,x['humidity']),axis=1),6)
    # entalpy
    my_dfs2[key]['enthalpy']=round(my_dfs2[key].apply(lambda x: h_humid_air(x['temperature']+273.15,x['humidity']),axis=1),1)
    # dew point
    my_dfs2[key]['dewpoint']=round(my_dfs2[key].apply(lambda x: T_dew(x['temperature']+273.15,x['humidity']),axis=1)-273.15,2)
    # density
    my_dfs2[key]['density']=round(my_dfs2[key].apply(lambda x: rho_Humid_air(x['temperature']+273.15,x['humidity']),axis=1),3)

# %%
#display data
if False:
    for key in my_dfs2.keys():
        print(40*'-'+'\n'+key)
        my_dfs2[key].head(5)
        print(40*'-')

# %%
my_dfs2['df_c'].tail()
# Out:
#                datetime  temperature  humidity  pressure  windspeed  winddir  \
# 622 2020-04-15 08:29:02         5.63        72      1021        6.7    260.0
# 623 2020-04-15 09:27:40         6.38        70      1022        7.2    270.0
# 624 2020-04-15 10:33:26         8.16        65      1022        8.2    270.0
# 625 2020-04-15 11:26:12         9.12        65      1022        7.7    260.0
# 626 2020-04-15 12:35:55        11.72        53      1021        7.2    270.0
#
#      cloudcoverage  rain  snow        weather_description  humidity_abs  \
# 622             75   0.0   0.0     Clouds : broken clouds      0.004047
# 623             40   0.0   0.0  Clouds : scattered clouds      0.004145
# 624             75   0.0   0.0     Clouds : broken clouds      0.004349
# 625             75   0.0   0.0     Clouds : broken clouds      0.004643
# 626             20   0.0   0.0        Clouds : few clouds      0.004503
#
#      enthalpy  dewpoint  density
# 622      15.9      1.07    1.263
# 623      16.9      1.40    1.259
# 624      19.2      2.06    1.251
# 625      21.0      2.97    1.247
# 626      23.3      2.54    1.235

# %% [markdown]
# ## Data report

# %%
# long
#profile report inline

if False: # Train Data report generation
    for key in my_dfs2.keys():
        title="Berlin Weather Data "+str(key)
        output_file="profile_report/Berlin Weather Data "+str(key)+".html"
        profile = my_dfs2[key].profile_report(title=title) 
        profile.to_file(output_file=output_file) # save the report

# %%
# short
if False: # hist report
    for key in my_dfs2.keys():
        my_dfs2[key].head()
        my_dfs2[key].info()
        my_dfs2[key].describe(include='all')
        
my_dfs2['df_c'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             627 non-null    datetime64[ns]
#  1   temperature          627 non-null    float64
#  2   humidity             627 non-null    int64
#  3   pressure             627 non-null    int64
#  4   windspeed            627 non-null    float64
#  5   winddir              627 non-null    float64
#  6   cloudcoverage        627 non-null    int64
#  7   rain                 627 non-null    float64
#  8   snow                 627 non-null    float64
#  9   weather_description  627 non-null    object
#  10  humidity_abs         627 non-null    float64
#  11  enthalpy             627 non-null    float64
#  12  dewpoint             627 non-null    float64
#  13  density              627 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(1)
# memory usage: 68.7+ KB

# %% [markdown]
# ## Heat map

# %%
sns.heatmap(my_dfs2['df_c'].isnull(), cbar=False)

# %%
sns.heatmap(my_dfs2['df_6'].isnull(), cbar=False)

# %% [markdown]
# # Display

# %%
# settings

#To revert to the original setting :
InteractiveShell.ast_node_interactivity = "last_expr"
# %matplotlib notebook

# %%
my_disp_dfs=my_dfs2
for key in my_disp_dfs.keys():
    my_disp_dfs[key].set_index('datetime',inplace=True)

# %%
# last 8 days    
my_disp_dfs['df_c']=my_disp_dfs['df_c'].loc[my_disp_dfs['df_c'].index>=my_disp_dfs['df_c'].index.max()-dt.timedelta(days=7)]

# %%
my_disp_dfs['df_c'].columns
# Out:
# Index(['temperature', 'humidity', 'pressure', 'windspeed', 'winddir',
#        'cloudcoverage', 'rain', 'snow', 'weather_description', 'humidity_abs',
#        'enthalpy', 'dewpoint', 'density'],
#       dtype='object')

# %%
# %matplotlib notebook
var='temperature'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
# %matplotlib notebook
var='pressure'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
# %matplotlib notebook
var='rain'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %% [markdown]
# # Maschine Learning prediction
