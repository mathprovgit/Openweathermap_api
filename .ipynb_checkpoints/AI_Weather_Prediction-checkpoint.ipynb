# %% [markdown]
# # Objectives

# %% [markdown]
# - [x] get data from database
# - [x] data wrangling
# - [x] data visualisation
# - [ ] ml model
# - [ ] compare with traditional prediction

# %% [markdown]
# # source

# %% [markdown]
#  data provided by Openweathermap

# %% [markdown]
# # settings

# %%
# settings
# display all outputs
from IPython.core.interactiveshell import InteractiveShell  
InteractiveShell.ast_node_interactivity = "all"
#To revert to the original setting :
# InteractiveShell.ast_node_interactivity = "last_expr"

# %% [markdown]
# # Imports

# %%
# os
import os

#import time
import time
import datetime as dt

#googlesheets
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g

# data analysis and wrangling
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random 

# visualization and reporting
import pandas_profiling # dataframe profiling @
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import calmap

# Humid air model
from media_model_humid_air import h_humid_air,T_dew, rho_Humid_air, Ha_air

# %% [markdown]
# # Data imports

# %% [markdown]
# ## Historical weather

# %% [markdown]
# ### google sheet authentication

# %%
#authentication to google api using JSON credential file
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('api_data/WDcred.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### get data

# %%
#get historical weather berlin sheet
hist_weather = client.open('current_weather_berlin').sheet1

data = hist_weather.get_all_values()
headers = data.pop(0)

df_historical = pd.DataFrame(data, columns=headers)

# %%
#df_historical.tail()

# %% [markdown]
# ## get Openweathermap forecast

# %% [markdown]
# ###  Authentication

# %%
#authentication to google api using JSON credential file
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('api_data/WDcred2.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### Get Data

# %%
# open workbook
forecast_weather = client.open('forecast_weather_berlin')

# %%
#see all worksheets
#forecast_weather.worksheets()

# %%
# dataframe dictionary with all data
my_dfs={}
for worksheet in forecast_weather.worksheets():
    data = worksheet.get_all_values()
    headers = data.pop(0)
    name = str(worksheet)
    name = "df_"+name.split("'")[1].split(" ")[0]  
    df = pd.DataFrame(data, columns=headers)
    my_dfs[name]=df

# %%
#display data
if False:
    for key in my_dfs.keys():
        print(40*'-'+'\n'+key)
        my_dfs[key].head(5)
        print(40*'-')

# %%
df_hist=df_historical
my_dfs2=my_dfs

# %%
df_historical.tail()
# Out:
#                  datetime temperature humidity pressure windspeed winddir  \
# 1273  2020-05-12 12:14:01       10.27       59     1016      5.28     277
# 1274  2020-05-12 13:15:20       10.04       58     1016      5.82     274
# 1275  2020-05-12 14:11:06       10.01       47     1016       7.2     240
# 1276  2020-05-12 15:15:37       10.45       57     1016       7.2     260
# 1277  2020-05-12 16:16:10       11.43       42     1016       7.7     260
#
#      cloudcoverage  rain snow weather       description weathericon  \
# 1273            18  0.25    0    Rain        light rain         10d
# 1274            35  0.15    0    Rain        light rain         10d
# 1275            75     0    0  Clouds     broken clouds         04d
# 1276            75     0    0  Clouds     broken clouds         04d
# 1277            40     0    0  Clouds  scattered clouds         03d
#
#      sunrisetime sunsettime
# 1273    05:14:32   20:51:00
# 1274    05:14:32   20:51:00
# 1275    05:14:32   20:51:00
# 1276    05:14:32   20:51:00
# 1277    05:14:32   20:51:00

# %% [markdown]
# # Wrangle

# %% [markdown]
# ## get ride of sunrise and sunset

# %%
df_hist.drop('sunrisetime',axis =1, inplace=True)
df_hist.drop('sunsettime',axis =1, inplace=True)

# %% [markdown]
# ## df_forecast column rename

# %%
for key in my_dfs2.keys():
    my_dfs2[key].rename(columns={
        '':'datetime',
        "temp": "temperature",
        "humidity": "humidity",
        "pressure": "pressure",
        "wind_speed": "windspeed",
        "wind_dir": "winddir",
        "rain3h":"rain",
        "snow3h":"snow",
        "cloudcoverage": "cloudcoverage",
        "weather": "weather",
        "description": "description",
        "icon": "weathericon"},inplace=True)
#df_fore.columns

# %% [markdown]
# ## join df

# %%
name='df_c'
my_dfs2[name]=df_hist

# %% [markdown]
# ## drop icon

# %%
for key in my_dfs2.keys():
    my_dfs2[key].drop('weathericon',axis =1, inplace=True)

# %% [markdown]
# ## string to numeric values

# %%
for key in my_dfs2.keys():
    cols=['temperature', 'humidity', 'pressure', 'windspeed','winddir','cloudcoverage','rain','snow']
    for col in cols:
        my_dfs2[key][col]= pd.to_numeric(my_dfs2[key][col], errors='coerce')

# %% [markdown]
# ## String to datetime

# %%
for key in my_dfs2.keys():
    my_dfs2[key]['datetime']= pd.to_datetime(my_dfs2[key]['datetime'], errors='coerce')

# %% [markdown]
# ## Time shift

# %%
for key in my_dfs2.keys():
    if key!='df_c':
        my_dfs2[key].datetime=my_dfs2[key].datetime+dt.timedelta(hours=3,minutes=0)
        #print(key)

# %% [markdown]
# ## weather and description

# %%
for key in my_dfs2.keys():
    my_dfs2[key]['weather_description']=my_dfs2[key]['weather']+' : '+my_dfs2[key]['description']
    my_dfs2[key].drop(['weather','description'],axis=1,inplace=True)

# %% [markdown]
# ## Deal with Na

# %%
for key in my_dfs2.keys():
    my_dfs2[key]['winddir'].fillna(399,inplace=True)

# %% [markdown]
# ## Creation new value

# %%
for key in my_dfs2.keys():  
    # absolute humidity
    my_dfs2[key]['humidity_abs']=round(my_dfs2[key].apply(lambda x: Ha_air(x['temperature']+273.15,x['humidity']),axis=1),6)
    # entalpy
    my_dfs2[key]['enthalpy']=round(my_dfs2[key].apply(lambda x: h_humid_air(x['temperature']+273.15,x['humidity']),axis=1),1)
    # dew point
    my_dfs2[key]['dewpoint']=round(my_dfs2[key].apply(lambda x: T_dew(x['temperature']+273.15,x['humidity']),axis=1)-273.15,2)
    # density
    my_dfs2[key]['density']=round(my_dfs2[key].apply(lambda x: rho_Humid_air(x['temperature']+273.15,x['humidity']),axis=1),3)

# %%
#display data
if False:
    for key in my_dfs2.keys():
        print(40*'-'+'\n'+key)
        my_dfs2[key].head(5)
        print(40*'-')

# %%
my_dfs2['df_c'].tail()
# Out:
#                 datetime  temperature  humidity  pressure  windspeed  winddir  \
# 1273 2020-05-12 12:14:01        10.27        59      1016       5.28    277.0
# 1274 2020-05-12 13:15:20        10.04        58      1016       5.82    274.0
# 1275 2020-05-12 14:11:06        10.01        47      1016       7.20    240.0
# 1276 2020-05-12 15:15:37        10.45        57      1016       7.20    260.0
# 1277 2020-05-12 16:16:10        11.43        42      1016       7.70    260.0
#
#       cloudcoverage  rain  snow        weather_description  humidity_abs  \
# 1273             18  0.25   0.0          Rain : light rain      0.004553
# 1274             35  0.15   0.0          Rain : light rain      0.004406
# 1275             75  0.00   0.0     Clouds : broken clouds      0.003558
# 1276             75  0.00   0.0     Clouds : broken clouds      0.004451
# 1277             40  0.00   0.0  Clouds : scattered clouds      0.003495
#
#       enthalpy  dewpoint  density
# 1273      21.9      2.69    1.242
# 1274      21.3      2.24    1.243
# 1275      19.2     -0.68    1.244
# 1276      21.8      2.38    1.241
# 1277      20.5     -0.92    1.237

# %% [markdown]
# ## Data report

# %%
# long
#profile report inline

if False: # Train Data report generation
    for key in my_dfs2.keys():
        title="Berlin Weather Data "+str(key)
        output_file="profile_report/Berlin Weather Data "+str(key)+".html"
        profile = my_dfs2[key].profile_report(title=title) 
        profile.to_file(output_file=output_file) # save the report

# %%
# short
if False: # hist report
    for key in my_dfs2.keys():
        my_dfs2[key].head()
        my_dfs2[key].info()
        my_dfs2[key].describe(include='all')
        
my_dfs2['df_c'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             1278 non-null   datetime64[ns]
#  1   temperature          1278 non-null   float64
#  2   humidity             1278 non-null   int64
#  3   pressure             1278 non-null   int64
#  4   windspeed            1278 non-null   float64
#  5   winddir              1278 non-null   float64
#  6   cloudcoverage        1278 non-null   int64
#  7   rain                 1278 non-null   float64
#  8   snow                 1278 non-null   float64
#  9   weather_description  1278 non-null   object
#  10  humidity_abs         1278 non-null   float64
#  11  enthalpy             1278 non-null   float64
#  12  dewpoint             1278 non-null   float64
#  13  density              1278 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(1)
# memory usage: 139.9+ KB

# %% [markdown]
# ## Heat map

# %%
sns.heatmap(my_dfs2['df_c'].isnull(), cbar=False)

# %%
sns.heatmap(my_dfs2['df_6'].isnull(), cbar=False)

# %% [markdown]
# # Display

# %%
# settings

#To revert to the original setting :
InteractiveShell.ast_node_interactivity = "last_expr"
# %matplotlib notebook

# %%
my_disp_dfs=my_dfs2
for key in my_disp_dfs.keys():
    my_disp_dfs[key].set_index('datetime',inplace=True)

# %%
# last 8 days    
my_disp_dfs['df_c']=my_disp_dfs['df_c'].loc[my_disp_dfs['df_c'].index>=my_disp_dfs['df_c'].index.max()-dt.timedelta(days=7)]

# %%
my_disp_dfs['df_c'].columns
# Out:
# Index(['temperature', 'humidity', 'pressure', 'windspeed', 'winddir',
#        'cloudcoverage', 'rain', 'snow', 'weather_description', 'humidity_abs',
#        'enthalpy', 'dewpoint', 'density'],
#       dtype='object')

# %%
#temperature chart
# %matplotlib notebook
var='temperature'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
#pressure chart
# %matplotlib notebook
var='pressure'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
# Rain chart
# %matplotlib notebook
var='rain'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
# cloudcoverage chart
# %matplotlib notebook
var='cloudcoverage'

plt.figure(figsize=(14,6))
plt.title(var +' in Berlin')
ax=my_disp_dfs['df_c'][var].plot(linewidth=1,marker='.',markersize=5)
if True:
    for key in my_disp_dfs.keys():
        if key !='df_c':
            my_disp_dfs[key][var].plot(ax=ax,label='forecast '+str(my_disp_dfs[key].index.min().date()),
                                   linewidth=0.1,
                                   linestyle='dashed',
                                   marker='*',
                                  markersize=7)
plt.xlabel('datetime')
plt.ylabel(var)
plt.xlim((dt.datetime.now()-dt.timedelta(days=3),dt.datetime.now()+dt.timedelta(days=3)))
plt.legend(loc='best')
plt.grid()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %% [markdown]
# # Maschine Learning prediction
