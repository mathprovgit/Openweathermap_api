# %% [markdown]
# # Infos

# %% [markdown]
# source
# - https://www.geeksforgeeks.org/python-find-current-weather-of-any-city-using-openweathermap-api/
# - https://openweathermap.org/

# %% [markdown]
# # import packages

# %%
#import pandas as pd
#import numpy as np
#import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
#import requests, json 
from  myfunc import get_api_data, weather_data_call,format_forecast
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g

# %% [markdown]
# # import API Key

# %%
# use self made func
data=get_api_data("api_data/info.txt")
#arrange data
api_key=data[0][:-1]
#base_url_current=data[1][:-1]
base_url_forcast=data[2][:-1]
city_name=data[3][:-1]

# %% [markdown]
# # Get Data via API Call

# %%
request=weather_data_call(api_key,base_url_forcast,city_name)

# %%
#see result
#request.content
request.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1585656000,
#    'main': {'temp': 279.16,
#     'feels_like': 275.58,
#     'temp_min': 277.97,
#     'temp_max': 279.16,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1025,
#     'humidity': 61,
#     'temp_kf': 1.19},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 2.09, 'deg': 347},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-03-31 12:00:00'},
#   {'dt': 1585666800,
#    'main': {'temp': 279.39,
#     'feels_like': 275.29,
#     'temp_min': 278.5,
#     'temp_max': 279.39,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 60,
#     'temp_kf': 0.89},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.83, 'deg': 315},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-03-31 15:00:00'},
#   {'dt': 1585677600,
#    'main': {'temp': 276.37,
#     'feels_like': 272.68,
#     'temp_min': 275.77,
#     'temp_max': 276.37,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 75,
#     'temp_kf': 0.6},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 2.27, 'deg': 302},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-03-31 18:00:00'},
#   {'dt': 1585688400,
#    'main': {'temp': 274.67,
#     'feels_like': 271.18,
#     'temp_min': 274.37,
#     'temp_max': 274.67,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 82,
#     'temp_kf': 0.3},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.9, 'deg': 258},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-03-31 21:00:00'},
#   {'dt': 1585699200,
#    'main': {'temp': 273.4,
#     'feels_like': 268.92,
#     'temp_min': 273.4,
#     'temp_max': 273.4,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1021,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.21, 'deg': 245},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-01 00:00:00'},
#   {'dt': 1585710000,
#    'main': {'temp': 272.65,
#     'feels_like': 268.05,
#     'temp_min': 272.65,
#     'temp_max': 272.65,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1018,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.33, 'deg': 246},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-01 03:00:00'},
#   {'dt': 1585720800,
#    'main': {'temp': 273.68,
#     'feels_like': 268.48,
#     'temp_min': 273.68,
#     'temp_max': 273.68,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1017,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.25, 'deg': 247},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-01 06:00:00'},
#   {'dt': 1585731600,
#    'main': {'temp': 278.55,
#     'feels_like': 273.01,
#     'temp_min': 278.55,
#     'temp_max': 278.55,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1015,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 4.74, 'deg': 254},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-01 09:00:00'},
#   {'dt': 1585742400,
#    'main': {'temp': 281.62,
#     'feels_like': 276.17,
#     'temp_min': 281.62,
#     'temp_max': 281.62,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1013,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 4.78, 'deg': 263},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-01 12:00:00'},
#   {'dt': 1585753200,
#    'main': {'temp': 280.69,
#     'feels_like': 275.12,
#     'temp_min': 280.69,
#     'temp_max': 280.69,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.03, 'deg': 270},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-01 15:00:00'},
#   {'dt': 1585764000,
#    'main': {'temp': 278.33,
#     'feels_like': 273.82,
#     'temp_min': 278.33,
#     'temp_max': 278.33,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1010,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.51, 'deg': 250},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-01 18:00:00'},
#   {'dt': 1585774800,
#    'main': {'temp': 277.24,
#     'feels_like': 272.36,
#     'temp_min': 277.24,
#     'temp_max': 277.24,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 4.18, 'deg': 259},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-01 21:00:00'},
#   {'dt': 1585785600,
#    'main': {'temp': 276.28,
#     'feels_like': 271.59,
#     'temp_min': 276.28,
#     'temp_max': 276.28,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 3.94, 'deg': 267},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-02 00:00:00'},
#   {'dt': 1585796400,
#    'main': {'temp': 275.23,
#     'feels_like': 270.52,
#     'temp_min': 275.23,
#     'temp_max': 275.23,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 3.82, 'deg': 257},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-02 03:00:00'},
#   {'dt': 1585807200,
#    'main': {'temp': 276.04,
#     'feels_like': 270.84,
#     'temp_min': 276.04,
#     'temp_max': 276.04,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 4.51, 'deg': 252},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-02 06:00:00'},
#   {'dt': 1585818000,
#    'main': {'temp': 280.42,
#     'feels_like': 274.62,
#     'temp_min': 280.42,
#     'temp_max': 280.42,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 5.36, 'deg': 257},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-02 09:00:00'},
#   {'dt': 1585828800,
#    'main': {'temp': 281.94,
#     'feels_like': 275.92,
#     'temp_min': 281.94,
#     'temp_max': 281.94,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 5.66, 'deg': 250},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-02 12:00:00'},
#   {'dt': 1585839600,
#    'main': {'temp': 281.66,
#     'feels_like': 275.27,
#     'temp_min': 281.66,
#     'temp_max': 281.66,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1003,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 6.19, 'deg': 253},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-02 15:00:00'},
#   {'dt': 1585850400,
#    'main': {'temp': 280.55,
#     'feels_like': 274.69,
#     'temp_min': 280.55,
#     'temp_max': 280.55,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.57, 'deg': 246},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-02 18:00:00'},
#   {'dt': 1585861200,
#    'main': {'temp': 280.28,
#     'feels_like': 273.86,
#     'temp_min': 280.28,
#     'temp_max': 280.28,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.46, 'deg': 251},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-02 21:00:00'},
#   {'dt': 1585872000,
#    'main': {'temp': 279.22,
#     'feels_like': 272.7,
#     'temp_min': 279.22,
#     'temp_max': 279.22,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 6.79, 'deg': 253},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-03 00:00:00'},
#   {'dt': 1585882800,
#    'main': {'temp': 278.72,
#     'feels_like': 272.8,
#     'temp_min': 278.72,
#     'temp_max': 278.72,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 6.12, 'deg': 285},
#    'rain': {'3h': 0.71},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-03 03:00:00'},
#   {'dt': 1585893600,
#    'main': {'temp': 277.65,
#     'feels_like': 271.62,
#     'temp_min': 277.65,
#     'temp_max': 277.65,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 5.67, 'deg': 277},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-03 06:00:00'},
#   {'dt': 1585904400,
#    'main': {'temp': 280.57,
#     'feels_like': 273.81,
#     'temp_min': 280.57,
#     'temp_max': 280.57,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 6.66, 'deg': 282},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-03 09:00:00'},
#   {'dt': 1585915200,
#    'main': {'temp': 282.59,
#     'feels_like': 275.7,
#     'temp_min': 282.59,
#     'temp_max': 282.59,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 6.8, 'deg': 284},
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-03 12:00:00'},
#   {'dt': 1585926000,
#    'main': {'temp': 282.85,
#     'feels_like': 276.39,
#     'temp_min': 282.85,
#     'temp_max': 282.85,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 6.24, 'deg': 288},
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-03 15:00:00'},
#   {'dt': 1585936800,
#    'main': {'temp': 280.03,
#     'feels_like': 275.19,
#     'temp_min': 280.03,
#     'temp_max': 280.03,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 3.96, 'deg': 290},
#    'rain': {'3h': 0.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-03 18:00:00'},
#   {'dt': 1585947600,
#    'main': {'temp': 277.68,
#     'feels_like': 273.19,
#     'temp_min': 277.68,
#     'temp_max': 277.68,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 3.36, 'deg': 305},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-03 21:00:00'},
#   {'dt': 1585958400,
#    'main': {'temp': 275.96,
#     'feels_like': 272.14,
#     'temp_min': 275.96,
#     'temp_max': 275.96,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1017,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 2.42, 'deg': 298},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-04 00:00:00'},
#   {'dt': 1585969200,
#    'main': {'temp': 274.68,
#     'feels_like': 271.43,
#     'temp_min': 274.68,
#     'temp_max': 274.68,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1018,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.63, 'deg': 294},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-04 03:00:00'},
#   {'dt': 1585980000,
#    'main': {'temp': 275.68,
#     'feels_like': 272.91,
#     'temp_min': 275.68,
#     'temp_max': 275.68,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1020,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.93, 'deg': 276},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-04 06:00:00'},
#   {'dt': 1585990800,
#    'main': {'temp': 280.96,
#     'feels_like': 278.28,
#     'temp_min': 280.96,
#     'temp_max': 280.96,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1021,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.8, 'deg': 206},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-04 09:00:00'},
#   {'dt': 1586001600,
#    'main': {'temp': 284.21,
#     'feels_like': 281.46,
#     'temp_min': 284.21,
#     'temp_max': 284.21,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1022,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 0.82, 'deg': 186},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-04 12:00:00'},
#   {'dt': 1586012400,
#    'main': {'temp': 284.83,
#     'feels_like': 281.72,
#     'temp_min': 284.83,
#     'temp_max': 284.83,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1021,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.31, 'deg': 147},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-04 15:00:00'},
#   {'dt': 1586023200,
#    'main': {'temp': 281.84,
#     'feels_like': 277.81,
#     'temp_min': 281.84,
#     'temp_max': 281.84,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1021,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.74, 'deg': 119},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-04 18:00:00'},
#   {'dt': 1586034000,
#    'main': {'temp': 279.76,
#     'feels_like': 274.93,
#     'temp_min': 279.76,
#     'temp_max': 279.76,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.89, 'deg': 112},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-04 21:00:00'},
#   {'dt': 1586044800,
#    'main': {'temp': 278.65,
#     'feels_like': 273.67,
#     'temp_min': 278.65,
#     'temp_max': 278.65,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1022,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 4.17, 'deg': 131},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-05 00:00:00'},
#   {'dt': 1586055600,
#    'main': {'temp': 277.85,
#     'feels_like': 272.83,
#     'temp_min': 277.85,
#     'temp_max': 277.85,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1021,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 4.23, 'deg': 134},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-04-05 03:00:00'},
#   {'dt': 1586066400,
#    'main': {'temp': 278.66,
#     'feels_like': 273.38,
#     'temp_min': 278.66,
#     'temp_max': 278.66,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1021,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.59, 'deg': 143},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-05 06:00:00'},
#   {'dt': 1586077200,
#    'main': {'temp': 284.74,
#     'feels_like': 279.28,
#     'temp_min': 284.74,
#     'temp_max': 284.74,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1020,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 5.1, 'deg': 151},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-04-05 09:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 7200,
#   'sunrise': 1585629729,
#   'sunset': 1585676303}}

# %% [markdown]
# # export CSV

# %% [markdown]
# ## Format result

# %%
df_weather=format_forecast(request)

# %%
df_weather.head()
# Out:
#                      temp_f  humidity_f  pressure_f  wind_speed_f  wind_dir_f  \
# datetime_f
# 2020-03-31 12:00:00    6.01          61        1030          2.09         347
# 2020-03-31 15:00:00    6.24          60        1029          2.83         315
# 2020-03-31 18:00:00    3.22          75        1028          2.27         302
# 2020-03-31 21:00:00    1.52          82        1028          1.90         258
# 2020-04-01 00:00:00    0.25          86        1026          3.21         245
#
#                      cloudcoverage_f weather_f    description_f icon_f
# datetime_f
# 2020-03-31 12:00:00               51    Clouds    broken clouds    04d
# 2020-03-31 15:00:00              100    Clouds  overcast clouds    04d
# 2020-03-31 18:00:00               89    Clouds  overcast clouds    04n
# 2020-03-31 21:00:00                0     Clear        clear sky    01n
# 2020-04-01 00:00:00                0     Clear        clear sky    01n

# %%
len(df_weather)
# Out:
# 40

# %% [markdown]
# ## Export to csv

# %%
export_file_name=''
export_file_name='forecast/forcast_'+str(df_weather.index[0]).replace(' ','_').replace(':','-')+'.csv'
export_file_name
# Out:
# 'forecast/forcast_2020-03-31_12-00-00.csv'

# %%
#df_weather.to_csv(export_file_name,sep=',')

# %% [markdown]
# ## Plot

# %%
if True:
    plt.figure(figsize=(14,6))
    df_weather['temp_f'].plot()
    plt.xlabel('Date time')
    plt.ylabel('Temperature')
    plt.title('\nTemperature in Berlin\n')
    plt.grid()
    plt.legend()
    plt.show()

# %% [markdown]
# # Export Json database

# %%
##print
#request.content
#request.json()

# %%
##write Json
#export_file_name=''
#export_file_name='forecast/forcast_'+str(df_weather.index[0]).replace(' ','_').replace(':','-')+'.json'

# %%
#with open(export_file_name, 'wb') as f:
#    f.write(request.content)

# %%
##read Json
#with open(export_file_name) as json_file:
#    data = json.load(json_file)
#    i=0
#    for p in data['list']:
#        if i<5:
#            print(p['main']['temp'])
#        i+=1

# %% [markdown]
# # google API

# %%
#authentication to google api using JSON credential file
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('api_data/WDcred.json', scope)
client = gspread.authorize(creds)

#get current weather berlin sheet
forecast_weather = client.open('forecast_weather_berlin')

# get workbook id
spreadsheet_key = forecast_weather.id

# %%
#see the content of the file
#forecast_weather.sheet1.get_all_values()

# %%
#write new data
wks_name='Sheet1'
d2g.upload(df_weather, spreadsheet_key, wks_name, credentials=creds, row_names=True)
# Out:
# <Worksheet 'Sheet1' id:0>
